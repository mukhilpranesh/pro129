# %% [markdown]
# <a href="https://colab.research.google.com/github/mukhilpranesh/pro129/blob/main/starsPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_load=files.upload()
# Out:
#      <input type="file" id="files-bdad68b6-9a95-473c-be88-0b138bdb7e8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdad68b6-9a95-473c-be88-0b138bdb7e8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import csv

df=pd.read_csv("dwarf_stars.csv")

df
# Out:
#      Unnamed: 0                      Star_name  Distance         Mass  Radius
# 0             0  SDSS J000013.54+255418.6 [de]      46.1           48    0.99
# 1             1        2MASS J00040288-6410358     192.0           19    1.63
# 2             2                      LHS 102BC       NaN          NaN     NaN
# 3             3        2MASS J00242463-0158201      37.7           79    1.09
# 4             4      2MASS J00250365+4759191AB     143.0          NaN     NaN
# ..          ...                            ...       ...          ...     ...
# 347         347                 WISE 2348-1028      54.1          NaN     NaN
# 348         348                 WISE 2357+1227      54.8          NaN     NaN
# 349         349                 WISE 2359-7335      42.7          NaN     NaN
# 350         350                WISEA 1101+5400     111.0          NaN     NaN
# 351         351                         2M1510     120.0  40 + 39 + ?     NaN
#
# [352 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Star_name', 'Distance', 'Mass', 'Radius'], dtype='object')

# %%
df.head()
# Out:
#                        Star_name  Distance Mass  Radius
# 0  SDSS J000013.54+255418.6 [de]      46.1   48    0.99
# 1        2MASS J00040288-6410358     192.0   19    1.63
# 2                      LHS 102BC       NaN  NaN     NaN
# 3        2MASS J00242463-0158201      37.7   79    1.09
# 4      2MASS J00250365+4759191AB     143.0  NaN     NaN

# %%
df.dropna()
# Out:
#                          Star_name  Distance Mass  Radius
# 0    SDSS J000013.54+255418.6 [de]      46.1   48    0.99
# 1          2MASS J00040288-6410358     192.0   19    1.63
# 3          2MASS J00242463-0158201      37.7   79    1.09
# 5          2MASS J00274197+0503417     236.0   31    1.44
# 7           2MASSW J0030300-145033      87.2   54    0.98
# ..                             ...       ...  ...     ...
# 187         2MASSI J2356547-155310      74.0   80    1.09
# 225                 WISE 0410+1502      20.0    6    1.17
# 229                WISE 0458+6434A      35.9   15    4.20
# 230                WISE 0458+6434B      35.9   10    3.80
# 284                 WISE 1405+5534      25.3   30    0.86
#
# [158 rows x 4 columns]

# %%
df.dtypes
# Out:
# Star_name     object
# Distance     float64
# Mass          object
# Radius       float64
# dtype: object

# %%
df["Mass"]=pd.to_numeric(df["Mass"],errors="coerce")
df["Radius"]=pd.to_numeric(df["Radius"])

# %%
radius = df['Radius'].to_list()
mass = df['Mass'].to_list()
gravity =[]
def convert_to_si(radius,mass):
   for i in range(0,len(radius)-1):
    radius[i] = radius[i]*6.957e+8
    mass[i] = mass[i]*1.989e+30
convert_to_si(radius,mass)

# %%
def gravity_calculation(radius,mass):
   G = 6.674e-11
   for index in range(0,len(mass)):
     g= (mass[index]*G)/((radius[index])**2)
     gravity.append(g)
gravity_calculation(radius,mass)
df["Gravity"] = gravity
df
# Out:
#                          Star_name  Distance  Mass  Radius       Gravity
# 0    SDSS J000013.54+255418.6 [de]      46.1  48.0    0.99  13432.220947
# 1          2MASS J00040288-6410358     192.0  19.0    1.63   1961.351224
# 2                        LHS 102BC       NaN   NaN     NaN           NaN
# 3          2MASS J00242463-0158201      37.7  79.0    1.09  18236.902412
# 4        2MASS J00250365+4759191AB     143.0   NaN     NaN           NaN
# ..                             ...       ...   ...     ...           ...
# 347                 WISE 2348-1028      54.1   NaN     NaN           NaN
# 348                 WISE 2357+1227      54.8   NaN     NaN           NaN
# 349                 WISE 2359-7335      42.7   NaN     NaN           NaN
# 350                WISEA 1101+5400     111.0   NaN     NaN           NaN
# 351                         2M1510     120.0   NaN     NaN           NaN
#
# [352 rows x 5 columns]

# %%
df.to_csv("star_with_gravity.csv")

# %%
df.dtypes
# Out:
# Star_name     object
# Distance     float64
# Mass         float64
# Radius       float64
# Gravity      float64
# dtype: object
